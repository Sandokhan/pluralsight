# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandokhan/pluralsight/blob/master/pluralsight_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learning the Matplotlib basics
#
# ---

# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 2.1.2

# %% [markdown]
# ###  Interactive mode
# In non-interactive mode you have to use the `plt.show()` in order to print the generete the plot. If you would like to see  if your Jupyter Notebook are with either non-interactive or interactive activated use the function `matplotlib.is_interactive()`. Also you can use one of the options bellow ether to activate or deactivate or interactive mode:
#
# `plt.ioff()`  or `matplotlib.interactive(False)` -> Turn off the interactive mode
# `plt.ion()`  or `matplotlib.interactive(True)`  -> Turn on the interactive mode
#
# In interactive mode you do not need to use the `plt.show()` function in order to plot your chart, but if you are in non-interactive mode you will need to.
#
# ---

# %%
import matplotlib.pyplot as plt

matplotlib.is_interactive()
# Out:
# True

# %%
plt.plot([2,4,6,8],
         [4,8,12,16])
# The first list represents the `x-axis`, the second the `y-axis`

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([2,4,6,8],
         [4,8,12,16],
         color='red')

# %%
plt.plot([2,4,6,8],
         [4,8,12,16])

plt.xlabel('x', fontsize=15, color='green')
plt.ylabel('2*x', fontsize=15, color='green')
# Out:
# Text(0,0.5,'2*x')

# %%
x = np.linspace(start=0, stop=10, num=50)

# %%
plt.plot(x, np.sin(x))

plt.xlabel('x', fontsize=15, color='green')
plt.ylabel('sin(x)', fontsize=15, color='green')
# Out:
# Text(0,0.5,'sin(x)')

# %%
plt.tick_params(axis='y',
                color='red',
                labelcolor='blue',
                labelsize='xx-large')

# %%
plt.tick_params(axis='x',
                bottom=False,
                labelbottom=False)

# %%
plt.plot(x, np.sin(x), label='sine curve')

plt.legend()

# %%
plt.plot(x, np.sin(x), label='sine curve')

plt.legend()
plt.title('Playing with Plots')
# Out:
# Text(0.5,1,'Playing with Plots')

# %%
plt.plot(x, np.sin(x), label='sine curve')

plt.legend()
plt.title('Playing with Plots')

plt.xlim(1,5)
#Set a limit for what x values are visible in the plot
# Out:
# (1, 5)

# %%
plt.plot(x, np.sin(x), label='sine curve')

plt.legend()
plt.title('Playing with Plots')

plt.xlim(1,5)
#Set a limit for what x values are visible in the plot
plt.ylim(-1,0.5)
#Set a limit for what y values are visible in the plot
# Out:
# (-1, 0.5)

# %%
plt.plot(x, np.sin(x), label='sine curve')

plt.legend()
plt.title('Playing with Plots')

plt.xlim(5,1)
#Set a limit for what x values are visible in the plot
plt.ylim(0.5,-1)
#Set a limit for what y values are visible in the plot
# Out:
# (0.5, -1)

# %%
plt.plot(x, np.sin(x))

plt.show()

# %%
plt.plot(x, np.sin(x), label='sine curve')
plt.plot(x, np.cos(x), label='cosine curve')

plt.legend()
plt.title('Playing with Plots')

plt.show()

# %%
plt.plot(x, np.sin(x), label='sine curve', color='red')
plt.plot(x, np.cos(x), label='cosine curve', color='m')

plt.legend()
plt.title('Playing with Plots')

plt.show()

# %%
random_array = np.random.randn(20)
plt.plot(random_array,
         color='green')

plt.show()

# %%
plt.plot(random_array,
         color='green',
         linestyle='--')

plt.show()

# %%
plt.plot(random_array,
         color='green',
         linestyle=':')

plt.show()

# %%
plt.plot(random_array,
         color='green',
         linestyle='--',
         linewidth=3)

plt.show()

# %%
plt.plot(random_array,
         color='green',
         marker='d')

plt.show()

# %%
plt.plot(random_array,
         color='green',
         marker='d',
         markersize= 10)

plt.show()

# %%
plt.plot(random_array,
         color='green',
         linestyle= 'None',
         marker='d')

plt.show()

# %%
plt.scatter(range(0,20),
            random_array,
            color='green',
            marker='d')

# %% [markdown]
# # Working with Figure and Axes
#
# ---

# %%
fig = plt.figure()

ax = fig.add_axes([0 , 0, 1, 1]) #[left, bottom, width, height]

plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_axes([0 , 0.6, 1, 0.4])

ax2 = fig.add_axes([0 , 0, 0.8, 0.4])

plt.show()

# %%
x = np.linspace(start=0, stop=10, num=50)

# %%
fig = plt.figure()

ax1 = fig.add_axes([0 , 0.6, 1, 0.4])
ax2 = fig.add_axes([0 , 0, 0.8, 0.4])

ax1.plot(x, np.sin(x))
ax2.plot(x, np.cos(x))

plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_axes([0 , 0.6, 1, 0.4])
ax2 = fig.add_axes([0 , 0, 0.8, 0.4])

ax1.plot(x, np.sin(x))
ax1.set_xlabel('x', fontsize=15, color='r')
ax1.set_ylabel('sin(x)', fontsize=15, color='r')

ax2.plot(x, np.cos(x))
ax2.set_xlabel('x', fontsize=15, color='r')
ax2.set_ylabel('cos(x)', fontsize=15, color='r')

plt.show()

# %%
fig = plt.figure()

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.5, 0.5, 0.4, 0.4])

plt.show()

# %% [markdown]
# ### Setting the size of the figure
#
# ---

# %%
fig = plt.figure(figsize=(8,8)) 
# By use the `figsize` argument we explicitly 
# set the figure width & height in inches

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.5, 0.5, 0.4, 0.4])

plt.show()

# %% [markdown]
# ### Subplots
#
# ---

# %%
fig = plt.figure(figsize=(8,8))

ax1 = fig.add_subplot(221)
# The argument in the `add_subplot`, defines a 2x2 grid &
# puts this fig in the top left position.

plt.show()

# %%
fig = plt.figure(figsize=(8,8))

ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4],
         [2, 4, 6, 8])

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

plt.show()

# %%
fig = plt.figure(figsize=(8,8))

ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4],
         [2, 4, 6, 8])

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

ax3 = fig.add_subplot(223)
ax3.plot(x, np.cos(x))

plt.show()

# %%
fig = plt.figure(figsize=(8,8))

ax1 = fig.add_subplot(221)
ax1.plot([1, 2, 3, 4],
         [2, 4, 6, 8])

ax2 = fig.add_subplot(222)
ax2.plot(x, np.sin(x))

ax3 = fig.add_subplot(224)
ax3.plot(x, np.cos(x))

plt.show()

# %%
# first tuple sets the grid, the second sets the position in the grid

ax1 = plt.subplot2grid((2,3),(0, 0))
ax1.plot(x, np.sin(x))
ax1.set_label('sine curve')

ax2 = plt.subplot2grid((2,3),(0, 1))
ax2.plot(x, np.cos(x))
ax2.set_label('cos curve')

ax3 = plt.subplot2grid((2,3),(0, 2), rowspan=2)
ax3.plot([1, 2, 3, 4],
         [2, 4, 6, 8])
ax3.set_label('straight line')
ax3.yaxis.tick_right()

ax4 = plt.subplot2grid((2,3),(1, 0), colspan=2)
ax4.plot(x, np.exp2(x))
ax4.set_label('exponential curve')

# %% [markdown]
# ### Watermarks
#
# ---

# %%
fig, ax = plt.subplots() 
#If you want to plot a single chart you can you this statement.

ax.plot([1, 2, 3, 4],
         [2, 4, 6, 8])

# %%
fig, ax = plt.subplots() 

ax.plot([1, 2, 3, 4],
         [2, 4, 6, 8])

ax.text(1, 4, 'A Sandokhan Production!',
        fontsize=12,
        color='red',
        ha='left',
        va='bottom',
        alpha=.6)
# Out:
# Text(1,4,'A Sandokhan Production!')

# %% [markdown]
# ### Visualizing Stock Data
#
# Now it's time to put all knowledge together.
#
# ---

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.style.use('seaborn-white')

# %%
print(plt.style.available)
# Out:
# ['seaborn', 'ggplot', 'seaborn-colorblind', 'seaborn-dark-palette', 'seaborn-dark', 'seaborn-pastel', 'dark_background', 'seaborn-poster', 'seaborn-talk', 'classic', 'seaborn-deep', 'fast', 'fivethirtyeight', 'seaborn-white', 'seaborn-bright', 'grayscale', 'seaborn-paper', 'seaborn-muted', 'seaborn-ticks', 'Solarize_Light2', 'bmh', '_classic_test', 'seaborn-notebook', 'seaborn-whitegrid', 'seaborn-darkgrid']

# %%
stock_data = pd.read_csv('datasets/stocks.csv')
stock_data.head()
# Out:
#        Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0  3-Jan-07  11.107141  38.869999  50.777351  251.001007  79.242500
# 1  1-Feb-07  10.962033  39.250000  48.082939  224.949951  74.503204
# 2  1-Mar-07  12.037377  41.700001  51.900383  229.309311  75.561348
# 3  2-Apr-07  12.930043  41.560001  54.588032  235.925919  81.934280
# 4  1-May-07  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %%
#Change the column Date from string to a date format

stock_data['Date'] = pd.to_datetime(stock_data['Date'])
stock_data.head()
# Out:
#         Date       AAPL       ADBE        CVX        GOOG        IBM  \
# 0 2007-01-03  11.107141  38.869999  50.777351  251.001007  79.242500
# 1 2007-02-01  10.962033  39.250000  48.082939  224.949951  74.503204
# 2 2007-03-01  12.037377  41.700001  51.900383  229.309311  75.561348
# 3 2007-04-02  12.930043  41.560001  54.588032  235.925919  81.934280
# 4 2007-05-01  15.701322  44.060001  57.598267  249.204208  85.786057
#
#         MDLZ       MSFT      NFLX       ORCL       SBUX
# 0  17.519524  24.118483  3.258571  15.696321  15.752188
# 1  16.019426  22.092464  3.218571  15.028588  13.930813
# 2  16.009354  21.857189  3.312857  16.583584  14.138198
# 3  16.924608  23.480597  3.167143  17.196436  13.984914
# 4  17.111704  24.146753  3.128572  17.726965  12.988567

# %%
fig = plt.figure(figsize=(10, 6))

ax1 = fig.add_axes([0, 0 , 1, 1])
ax2 = fig.add_axes([0.05, 0.65 , 0.5, 0.3])

plt.show()

# %%
fig = plt.figure(figsize=(10, 6))

ax1 = fig.add_axes([0, 0 , 1, 1])
ax2 = fig.add_axes([0.05, 0.65 , 0.5, 0.3])

ax1.plot(stock_data['Date'],
         stock_data['AAPL'],
         color='green')
ax1.set_title('APPL vs IBM (inset)')
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))

ax1 = fig.add_axes([0, 0 , 1, 1])
ax2 = fig.add_axes([0.05, 0.65 , 0.5, 0.3])

ax1.plot(stock_data['Date'],
         stock_data['AAPL'],
         color='green')
ax1.set_title('APPL vs IBM (inset)')

ax2.plot(stock_data['Date'],
         stock_data['IBM'],
         color='blue')
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))

fig.suptitle('Stock price comparison 2007-2017',
             fontsize=20)

ax1 = fig.add_subplot(221)
ax1.set_title('MSFT')
ax1.plot(stock_data['Date'],
         stock_data['MSFT'],
         color='green')

ax2 = fig.add_subplot(222)
ax2.set_title('GOOG')
ax2.plot(stock_data['Date'],
         stock_data['GOOG'],
         color='purple')

ax3 = fig.add_subplot(223)
ax3.set_title('SBUX')
ax3.plot(stock_data['Date'],
         stock_data['SBUX'],
         color='magenta')

ax4 = fig.add_subplot(224)
ax4.set_title('CVX')
ax4.plot(stock_data['Date'],
         stock_data['CVX'],
         color='orange')
